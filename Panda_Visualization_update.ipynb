# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("F:/Machine_Learning/Pandas/top_100_tallest_buildings_world.csv")
df.head(10)
# Out:
#                   Building Name          City               Country  \
# 0                  Burj Khalifa         Dubai  United Arab Emirates
# 1                   Merdeka 118  Kuala Lumpur              Malaysia
# 2                Shanghai Tower      Shanghai                 China
# 3     Abraj Al-Bait Clock Tower         Mecca          Saudi Arabia
# 4        Ping An Finance Centre      Shenzhen                 China
# 5             Lotte World Tower         Seoul           South Korea
# 6        One World Trade Center      New York         United States
# 7  Guangzhou CTF Finance Centre     Guangzhou                 China
# 8    Tianjin CTF Finance Centre       Tianjin                 China
# 9                     China Zun       Beijing                 China
#
#        Continent
# 0           Asia
# 1           Asia
# 2           Asia
# 3           Asia
# 4           Asia
# 5           Asia
# 6  North America
# 7           Asia
# 8           Asia
# 9           Asia

# %%
print(df.columns.tolist())
print(df.info()) 
print(df.isnull().sum())
# Out:
# ['Building Name', 'City', 'Country', 'Continent']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Building Name  74 non-null     object
#  1   City           74 non-null     object
#  2   Country        74 non-null     object
#  3   Continent      74 non-null     object
# dtypes: object(4)
# memory usage: 2.4+ KB
# None
# Building Name    0
# City             0
# Country          0
# Continent        0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.lower()
print(df.head())


continent_counts = df['continent'].value_counts()
continent_counts.plot(kind='barh', color='skyblue', edgecolor='black')
plt.title('Top 100 Tallest Buildings by Continent')
plt.xlabel('Number of Buildings')
plt.ylabel('Continent')
plt.show()
# Out:
#                building name          city               country continent
# 0               Burj Khalifa         Dubai  United Arab Emirates      Asia
# 1                Merdeka 118  Kuala Lumpur              Malaysia      Asia
# 2             Shanghai Tower      Shanghai                 China      Asia
# 3  Abraj Al-Bait Clock Tower         Mecca          Saudi Arabia      Asia
# 4     Ping An Finance Centre      Shenzhen                 China      Asia

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\Melasales.csv")
df.head(10)
# Out:
#    WEEK1  WEEK2  WEEK3
# 0   4500   6050   9000
# 1   5000   7000   4500
# 2   7600   6050   6900
# 3   5000   5678   4500
# 4   8999   6050   5432
# 5   5000   4322   4500
# 6   8700   6050   7000

# %%
df.plot(kind='line',color=['red','blue','green'])
plt.title("Mela Sales Report")
plt.xlabel("Days")
plt.ylabel("Price in TK")
plt.show()

# %%
df=pd.read_csv("D:\Melasaleswithdays.csv")

# %%
df.plot(kind='bar',color=['red','blue','green'])
plt.title("Mela Sales Report")
plt.xlabel("Days")
plt.ylabel("Price in TK")
plt.show()
