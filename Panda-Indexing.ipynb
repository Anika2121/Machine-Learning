# %%
import pandas as pd

# %%
data=pd.read_csv("F:/Machine_Learning/Pandas/top_100_tallest_buildings_world.csv")

# %%
data.head()
# Out:
#                Building Name          City               Country Continent
# 0               Burj Khalifa         Dubai  United Arab Emirates      Asia
# 1                Merdeka 118  Kuala Lumpur              Malaysia      Asia
# 2             Shanghai Tower      Shanghai                 China      Asia
# 3  Abraj Al-Bait Clock Tower         Mecca          Saudi Arabia      Asia
# 4     Ping An Finance Centre      Shenzhen                 China      Asia

# %%
data.City
# Out:
# 0            Dubai
# 1     Kuala Lumpur
# 2         Shanghai
# 3            Mecca
# 4         Shenzhen
#           ...
# 69           Dubai
# 70           Malmö
# 71    Philadelphia
# 72     Los Angeles
# 73         Chicago
# Name: City, Length: 74, dtype: object

# %%
data['City']
# Out:
# 0            Dubai
# 1     Kuala Lumpur
# 2         Shanghai
# 3            Mecca
# 4         Shenzhen
#           ...
# 69           Dubai
# 70           Malmö
# 71    Philadelphia
# 72     Los Angeles
# 73         Chicago
# Name: City, Length: 74, dtype: object

# %%
data['Country'][3]
# Out:
# 'Saudi Arabia'

# %%
data.iloc[0]
# Out:
# Building Name            Burj Khalifa
# City                            Dubai
# Country          United Arab Emirates
# Continent                        Asia
# Name: 0, dtype: object

# %%
data.iloc[:,0]
# Out:
# 0                  Burj Khalifa
# 1                   Merdeka 118
# 2                Shanghai Tower
# 3     Abraj Al-Bait Clock Tower
# 4        Ping An Finance Centre
#                 ...
# 69       Rose Rayhaan by Rotana
# 70                Turning Torso
# 71    Comcast Technology Center
# 72        Wilshire Grand Center
# 73          John Hancock Center
# Name: Building Name, Length: 74, dtype: object

# %%
data.iloc[:3,0]
# Out:
# 0      Burj Khalifa
# 1       Merdeka 118
# 2    Shanghai Tower
# Name: Building Name, dtype: object

# %%
data.iloc[1:3,0]
# Out:
# 1       Merdeka 118
# 2    Shanghai Tower
# Name: Building Name, dtype: object

# %%
data.iloc[-5:]
# Out:
#                 Building Name          City               Country  \
# 69     Rose Rayhaan by Rotana         Dubai  United Arab Emirates
# 70              Turning Torso         Malmö                Sweden
# 71  Comcast Technology Center  Philadelphia         United States
# 72      Wilshire Grand Center   Los Angeles         United States
# 73        John Hancock Center       Chicago         United States
#
#         Continent
# 69           Asia
# 70         Europe
# 71  North America
# 72  North America
# 73  North America

# %%
data.loc[73,'Building Name']
# Out:
# 'John Hancock Center'

# %%
data.City=='Dubai'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69     True
# 70    False
# 71    False
# 72    False
# 73    False
# Name: City, Length: 74, dtype: bool

# %%
data.loc[(data.City=='Shanghai')&(data.Country=='China')]
# Out:
#                       Building Name      City Country Continent
# 2                    Shanghai Tower  Shanghai   China      Asia
# 11  Shanghai World Financial Center  Shanghai   China      Asia
# 27                    Jin Mao Tower  Shanghai   China      Asia
# 43                       ICBC Tower  Shanghai   China      Asia
# 50       Shimao International Plaza  Shanghai   China      Asia
